# %% [markdown]
# ### Dependencies###

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
import json
import numpy as np

# %% [markdown]
# ### Helpful links: ###
# http://pandas-datareader.readthedocs.io/en/latest/remote_data.html#remote-data-morningstar
# https://pythonprogramming.net/getting-stock-prices-python-programming-for-finance/

# %%
start = dt.datetime(2017, 1, 1)
end = dt.datetime(2018, 2, 28)

df = web.DataReader('IBM', "morningstar", start, end)
#df.head()

# %%
#df = web.DataReader('TSLA', "morningstar", start, end)
#df.head()

# %%
# What we should do..2 tech stocks and 2 oil/energy?? Stocks =[IBM,AAPl,GOOG,]

# %%
df.to_csv("IBM.csv")

# %%
df1 = pd.read_csv("IBM.csv",parse_dates = True, index_col=0)
df1.head()
# Out:
#               Date   Close    High     Low    Open   Volume
# Symbol
# IBM     2017-01-02  165.99  165.99  165.99  165.99        0
# IBM     2017-01-03  167.19  167.87  166.01  167.00  2934119
# IBM     2017-01-04  169.26  169.87  167.36  167.77  3381432
# IBM     2017-01-05  168.70  169.39  167.26  169.25  2682181
# IBM     2017-01-06  169.53  169.92  167.52  168.69  2945536

# %%
style.use('ggplot')
df.plot()
plt.show()
