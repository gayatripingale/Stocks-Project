# %%
# Dependencies
import tweepy
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from datetime import datetime
import datetime
import time
import seaborn as sns
import pandas_datareader.data as web

# %%
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
from config import consumer_key, consumer_secret, \
    access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Filters
min_tweets = 5
lang = "en"

# %%
# Search terms
search_terms = ["$FB", "$AAPL", "$AMZN", "$NFLX", "$GOOG", "$GLD"]
search_terms1 = ["FB","AAPL","AMZN","NFLX","GOOG","GLD"]

# target_users = "@cnbc " or "@benzinga" or "@stocktwits"

# target_users = "@cnbc " or "@benzinga" or "@stocktwits" or "@breakoutstocks" \
#               or "@bespokeinvest" or "@WSJMarkets" or "@stephanie_link" or \
#              "@nytimesbusiness" or "@IBDinvestors " or "@WSJDealJournal"

# %%
# Date and time range
start = datetime.datetime(2018, 3, 5)
end = datetime.datetime(2018, 3, 9)

# Get Stock Data from Morningstar
stock_data = web.DataReader(search_terms1, "morningstar", start, end)

# Put Open and Close Data into Pandas DataFrame
df = pd.DataFrame(stock_data)[["Open", "Close"]]
df.head()
# Out:
#                      Open   Close
# Symbol Date
# FB     2018-03-05  176.20  180.40
#        2018-03-06  181.78  179.78
#        2018-03-07  178.74  183.71
#        2018-03-08  183.56  182.34
#        2018-03-09  183.91  185.23

# %%
df["Diff"] = df["Close"] - df["Open"]
#df.head()

df["Percent_Diff"] = (df["Diff"]/df["Open"])*100
df.head()
# Out:
#                      Open   Close  Diff  Percent_Diff
# Symbol Date
# FB     2018-03-05  176.20  180.40  4.20      2.383655
#        2018-03-06  181.78  179.78 -2.00     -1.100231
#        2018-03-07  178.74  183.71  4.97      2.780575
#        2018-03-08  183.56  182.34 -1.22     -0.664633
#        2018-03-09  183.91  185.23  1.32      0.717742

# %%
# Calculate total stock price change within the date specified
df1 = df.groupby("Symbol")["Percent_Diff"].sum()
df1
# Out:
# Symbol
# AAPL    2.240452
# AMZN    4.570065
# FB      4.117109
# GLD    -0.004848
# GOOG    6.041508
# NFLX    7.576157
# Name: Percent_Diff, dtype: float64

# %%
# Add data to Pandas DataFrame
df_df = pd.DataFrame(df1)
df_df
# Out:
#         Percent_Diff
# Symbol
# AAPL        2.240452
# AMZN        4.570065
# FB          4.117109
# GLD        -0.004848
# GOOG        6.041508
# NFLX        7.576157

# %%
# Reset index
diff_df = df_df.reset_index(drop = False)
diff_df
# Out:
#   Symbol  Percent_Diff
# 0   AAPL      2.240452
# 1   AMZN      4.570065
# 2     FB      4.117109
# 3    GLD     -0.004848
# 4   GOOG      6.041508
# 5   NFLX      7.576157

# %%
# Variables for holding sentiments
sentiments = []

# %%
# Date Range
startdate = datetime.datetime(2018, 3, 5, 0, 0, 0)
enddate = datetime.datetime(2018, 3, 9, 0, 0, 0)

# Loop through all search terms
for term in search_terms:
    
    counter = 1
    
    public_tweets = api.search(term, count = 200, since = startdate, until = enddate)
    
    for tweet in public_tweets["statuses"]:
        
        # Filter tweets
        if (tweet["user"]["statuses_count"] > min_tweets and
            tweet["user"]["lang"] == lang):
        
            # Run Vader Analysis on each tweets
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            tweets_ago = counter

            # Add sentiments for each tweets into an array
            sentiments.append({"Compound": compound,
                               "Positive": pos,
                               "Neutral": neu,
                               "Negative": neg,
                               "Tweets Ago": counter,
                               "Symbol": term,
                               "Date": tweet["created_at"],
                               "Tweet Text": tweet["text"]})

        # Add to counter
        counter = counter + 1
        
sentiments
# Out:
# [{'Compound': 0.0,
#   'Date': 'Thu Mar 08 23:25:53 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'Facebook Inc $FB CEO Sells $39,908,000.00 in Stock https://t.co/T05Hh2UoPu',
#   'Tweets Ago': 1},
#  {'Compound': 0.0258,
#   'Date': 'Thu Mar 08 14:40:03 +0000 2018',
#   'Negative': 0.187,
#   'Neutral': 0.526,
#   'Positive': 0.287,
#   'Symbol': '$FB',
#   'Tweet Text': 'The price of $fb has just reached a value of 183.00. New alert range: 182 - 184',
#   'Tweets Ago': 2},
#  {'Compound': 0.6124,
#   'Date': 'Thu Mar 08 14:35:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.667,
#   'Positive': 0.333,
#   'Symbol': '$FB',
#   'Tweet Text': 'The price of $fb has just reached a value of 182.00. New alert range: 181 - 183',
#   'Tweets Ago': 3},
#  {'Compound': 0.0258,
#   'Date': 'Thu Mar 08 14:31:04 +0000 2018',
#   'Negative': 0.187,
#   'Neutral': 0.526,
#   'Positive': 0.287,
#   'Symbol': '$FB',
#   'Tweet Text': 'The price of $fb has just reached a value of 181.00. New alert range: 180 - 182',
#   'Tweets Ago': 4},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 14:05:13 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '$FB\n183.71 USD 0.00 (0.00%)\nClosed: Mar 8, 9:03 AM EST · Disclaimer\nPre-market 183.39 −0.32 (0.17%)',
#   'Tweets Ago': 5},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 12:10:09 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'Insider Selling: Facebook Inc $FB CEO Sells $38,500,000.00 in Stock https://t.co/vpdGSCKgfh',
#   'Tweets Ago': 6},
#  {'Compound': 0.481,
#   'Date': 'Thu Mar 08 11:16:35 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 7},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 05:13:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'Facebook Inc $FB CEO Sells $39,410,800.00 in Stock https://t.co/ZWEw0t8BUv #stocks',
#   'Tweets Ago': 8},
#  {'Compound': 0.5267,
#   'Date': 'Wed Mar 07 23:01:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.779,
#   'Positive': 0.221,
#   'Symbol': '$FB',
#   'Tweet Text': '$FB is in Ichimoku Cloud Breakout winning 60.00% in the past. https://t.co/lEIPOXBX87 https://t.co/RXj8r5j9lC',
#   'Tweets Ago': 9},
#  {'Compound': 0.481,
#   'Date': 'Wed Mar 07 20:35:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 10},
#  {'Compound': 0.481,
#   'Date': 'Wed Mar 07 12:15:32 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 11},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 09:18:41 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'Facebook Inc $FB CEO Sells $38,500,000.00 in Stock https://t.co/xDYciinZf0',
#   'Tweets Ago': 12},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 08:02:37 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'Facebook COO Sheryl Sandberg Sells $9,610,700.00 in $FB https://t.co/Gv4fxeTK6L',
#   'Tweets Ago': 13},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:55:35 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '907 $FB May 205 Calls bought for $2.083 (sweep) @ 181.70\n$FB June $1MM 200 Calls bought for $4.00 (sweep) @ 180.30\n\n#UOA #UOAfb',
#   'Tweets Ago': 14},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 02:30:24 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'Facebook Inc $FB COO Sells $9,610,700.00 in Stock https://t.co/s65HTLei2X #stocks',
#   'Tweets Ago': 15},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 21:18:21 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '$FB high OI range is 180.00 to 180.00 for option expiration 03/16/2018 #maxpain #options https://t.co/2nmLR4zaok https://t.co/bsGzPOa3vu',
#   'Tweets Ago': 16},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 18:02:20 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '$1,020,000.00 of bullish unusual option activity detected for $FB https://t.co/qOLiV1KMfo https://t.co/KCfbdD6aPX',
#   'Tweets Ago': 17},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:28:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '$FB\n12:23 B 2,550 Jun 200 c @ 4.00',
#   'Tweets Ago': 18},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:26:41 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @SpeedyCalls: $FB JUN 200.00 Calls BUYING Activity https://t.co/7pqjqzKBYG',
#   'Tweets Ago': 19},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:24:15 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '$FB JUN 200.00 Calls BUYING Activity https://t.co/7pqjqzKBYG',
#   'Tweets Ago': 20},
#  {'Compound': 0.481,
#   'Date': 'Tue Mar 06 16:47:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 21},
#  {'Compound': 0.481,
#   'Date': 'Tue Mar 06 15:46:26 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 22},
#  {'Compound': 0.481,
#   'Date': 'Tue Mar 06 15:06:12 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 23},
#  {'Compound': 0.6124,
#   'Date': 'Tue Mar 06 14:45:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.667,
#   'Positive': 0.333,
#   'Symbol': '$FB',
#   'Tweet Text': 'The price of $fb has just reached a value of 180.00. New alert range: 179 - 181',
#   'Tweets Ago': 24},
#  {'Compound': 0.6124,
#   'Date': 'Tue Mar 06 14:40:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.667,
#   'Positive': 0.333,
#   'Symbol': '$FB',
#   'Tweet Text': 'The price of $fb has just reached a value of 179.00. New alert range: 178 - 180',
#   'Tweets Ago': 25},
#  {'Compound': 0.6124,
#   'Date': 'Tue Mar 06 14:35:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.667,
#   'Positive': 0.333,
#   'Symbol': '$FB',
#   'Tweet Text': 'The price of $fb has just reached a value of 178.00. New alert range: 177 - 179',
#   'Tweets Ago': 26},
#  {'Compound': 0.481,
#   'Date': 'Tue Mar 06 13:57:42 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.885,
#   'Positive': 0.115,
#   'Symbol': '$FB',
#   'Tweet Text': 'RT @Sandro_power: I posted this special update to buy $FB insided of PowerGroupTrades on friday mar 02  as it was below 175  the april 20 1…',
#   'Tweets Ago': 27},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:36:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$FB',
#   'Tweet Text': '$FB high OI range is 180.00 to 180.00 for option expiration 03/16/2018 #maxpain #options https://t.co/2nmLR4zaok https://t.co/dXciJWzYwD',
#   'Tweets Ago': 28},
#  {'Compound': 0.296,
#   'Date': 'Thu Mar 08 19:14:08 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.82,
#   'Positive': 0.18,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'Apple $AAPL PT Set at $180.00 by Rosenblatt Securities https://t.co/57WJ0vmGwx #stocks',
#   'Tweets Ago': 1},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 16:05:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'sold last three $GOOGL 1120c at 7.00 avg from 1.6 wednesday\n\n$SPy $SPX $AAPL $NFLX https://t.co/3iNj3KWVa8',
#   'Tweets Ago': 2},
#  {'Compound': 0.296,
#   'Date': 'Thu Mar 08 14:56:42 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.804,
#   'Positive': 0.196,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'Apple $AAPL Given a $180.00 Price Target at Rosenblatt Securities https://t.co/qn60CoyNJu',
#   'Tweets Ago': 3},
#  {'Compound': 0.1511,
#   'Date': 'Thu Mar 08 13:34:02 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.923,
#   'Positive': 0.077,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'https://t.co/0QaRk4AcAV &lt;- Want to make $600,00 In One Year Trading? Check out how this guy did it! $AAPL $MBLY $QQQ',
#   'Tweets Ago': 4},
#  {'Compound': 0.296,
#   'Date': 'Thu Mar 08 13:07:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.804,
#   'Positive': 0.196,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'Apple $AAPL Given a $180.00 Price Target at Rosenblatt Securities https://t.co/3DblC5eSTx',
#   'Tweets Ago': 5},
#  {'Compound': 0.3595,
#   'Date': 'Thu Mar 08 12:26:41 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.878,
#   'Positive': 0.122,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'RT @ForexStopHunter: $AAPL Going LIVE with Michael Lamothe @MichaelGLamothe Today 9:00 AM EST here https://t.co/5lsWdmTHe4 Join us!  Live S…',
#   'Tweets Ago': 6},
#  {'Compound': 0.3595,
#   'Date': 'Thu Mar 08 12:25:23 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.878,
#   'Positive': 0.122,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'RT @ForexStopHunter: $AAPL Going LIVE with Michael Lamothe @MichaelGLamothe Today 9:00 AM EST here https://t.co/5lsWdmTHe4 Join us!  Live S…',
#   'Tweets Ago': 7},
#  {'Compound': 0.3595,
#   'Date': 'Thu Mar 08 12:08:26 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.865,
#   'Positive': 0.135,
#   'Symbol': '$AAPL',
#   'Tweet Text': '$AAPL Going LIVE with Michael Lamothe @MichaelGLamothe Today 9:00 AM EST here https://t.co/5lsWdmTHe4 Join us!  Liv… https://t.co/m9YWwJsafQ',
#   'Tweets Ago': 8},
#  {'Compound': 0.4588,
#   'Date': 'Wed Mar 07 22:26:39 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.8,
#   'Positive': 0.2,
#   'Symbol': '$AAPL',
#   'Tweet Text': '$AAPL open interest for maturity 03/09/2018. High put=170.00 High call=180.00 #maxpain #options… https://t.co/gL2gUuytaw',
#   'Tweets Ago': 9},
#  {'Compound': 0.1511,
#   'Date': 'Wed Mar 07 18:32:05 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.923,
#   'Positive': 0.077,
#   'Symbol': '$AAPL',
#   'Tweet Text': 'https://t.co/0QaRk4AcAV &lt;- Want to make $600,00 In One Year Trading? Check out how this guy did it! $AAPL $MBLY $QQQ',
#   'Tweets Ago': 10},
#  {'Compound': 0.6249,
#   'Date': 'Tue Mar 06 19:54:58 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.779,
#   'Positive': 0.221,
#   'Symbol': '$AAPL',
#   'Tweet Text': '$BTC #BITCOIN $BTCUSD These support levels are in Play, 9200.00, 8400 and $5500.  $BTG $SPY $AAPL $AMZN $VIX $BABA… https://t.co/gn3o2emvwE',
#   'Tweets Ago': 11},
#  {'Compound': 0.34,
#   'Date': 'Tue Mar 06 16:22:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.806,
#   'Positive': 0.194,
#   'Symbol': '$AAPL',
#   'Tweet Text': '$amd MAR16P 12.00 in play still and added $aapl MAR16P 177.50',
#   'Tweets Ago': 12},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 16:30:37 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$AMZN',
#   'Tweet Text': '$AMZN Max Pain=1505.00. Maturity=03/09/2018. #maxpain #options https://t.co/VQf6FL5lPB https://t.co/zEG8XLJT0m',
#   'Tweets Ago': 1},
#  {'Compound': 0.2023,
#   'Date': 'Thu Mar 08 16:01:25 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.927,
#   'Positive': 0.073,
#   'Symbol': '$AMZN',
#   'Tweet Text': 'RT @PeteStock11: Will look at $CHCI above 1.75-1.85 for massive run 2.50-3.00 DC with Montgomery County MD and Northern VA) in Top 5 area f…',
#   'Tweets Ago': 2},
#  {'Compound': 0.7906,
#   'Date': 'Thu Mar 08 02:50:00 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.619,
#   'Positive': 0.381,
#   'Symbol': '$AMZN',
#   'Tweet Text': '$AMZN (https://t.co/Fq3jHWeomE Inc) strong gains with a close at $1,545.00, a 82.62% increase since 12 months ago… https://t.co/XO8GbEgp4s',
#   'Tweets Ago': 3},
#  {'Compound': 0.1779,
#   'Date': 'Wed Mar 07 04:37:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.884,
#   'Positive': 0.116,
#   'Symbol': '$AMZN',
#   'Tweet Text': '$AMZN 1513.00 Amazon envisions its Seattle campus expanding another two million square feet. https://t.co/k4lBESeVEI',
#   'Tweets Ago': 4},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 20:47:24 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$AMZN',
#   'Tweet Text': '$AMZN high OI range is 1500.00 to 1500.00 for option expiration 03/09/2018 #maxpain #options https://t.co/cIhUoLFJyN https://t.co/EyhECXNd1b',
#   'Tweets Ago': 5},
#  {'Compound': 0.6249,
#   'Date': 'Tue Mar 06 19:54:58 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.779,
#   'Positive': 0.221,
#   'Symbol': '$AMZN',
#   'Tweet Text': '$BTC #BITCOIN $BTCUSD These support levels are in Play, 9200.00, 8400 and $5500.  $BTG $SPY $AAPL $AMZN $VIX $BABA… https://t.co/gn3o2emvwE',
#   'Tweets Ago': 6},
#  {'Compound': -0.0772,
#   'Date': 'Thu Mar 08 22:49:54 +0000 2018',
#   'Negative': 0.106,
#   'Neutral': 0.804,
#   'Positive': 0.09,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX Netflix, Inc. - Common St Top stock up 133% from low. Close: 317.00 VolvsAvg: 0.87 Liq: $3494M https://t.co/xQxHlEnpfK',
#   'Tweets Ago': 1},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 19:14:23 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX Max Pain=310.00. Maturity=03/09/2018. #maxpain #options https://t.co/gs2a0034ej https://t.co/ef2yaHmkhu',
#   'Tweets Ago': 2},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 17:30:51 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX is now DOWN -$2.85. Now over that -$3.00',
#   'Tweets Ago': 3},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 16:05:04 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'sold last three $GOOGL 1120c at 7.00 avg from 1.6 wednesday\n\n$SPy $SPX $AAPL $NFLX https://t.co/3iNj3KWVa8',
#   'Tweets Ago': 4},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 15:56:26 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX is $315.17 and seen it in the $312.00 area early this week',
#   'Tweets Ago': 5},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 15:53:39 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'By $NFLX is DOWN -$5.74 and not going UP over -&amp;3.00 have me thinking that the market might turn ReD. Then back UP B4 close? 🤔',
#   'Tweets Ago': 6},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 15:31:58 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Mar 08 Thursday, $NFLX is $315.77\n\nSeeing $325.00',
#   'Tweets Ago': 7},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 14:51:38 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Netflix $NFLX Given New $330.00 Price Target at Macquarie https://t.co/yz5x14yq8i',
#   'Tweets Ago': 8},
#  {'Compound': -0.2244,
#   'Date': 'Wed Mar 07 23:59:11 +0000 2018',
#   'Negative': 0.119,
#   'Neutral': 0.881,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'RT @TraderFlorida: $NFLX Up $25.00+ from suggested buy entry – continue to raise\nstops. Congrat’s! https://t.co/7QMgE7Vz8g',
#   'Tweets Ago': 9},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 23:59:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'RT @TraderFlorida: $NFLX Up $39.00+ from suggested buy entry – Price target $345.00\narea. https://t.co/ZAV7tZfX7d',
#   'Tweets Ago': 10},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 21:23:05 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': "GOOGL 1120's 5.00 near close, entry 1.6\nGOOGL 1125s 3.00 near close, entry 1.05\n\nRiding  \n\n$SPy $SPX $NFLX",
#   'Tweets Ago': 11},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 20:41:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX high OI range is 310.00 to 320.00 for option expiration 03/09/2018 #maxpain #options https://t.co/LeAweAst3y https://t.co/SJszGKWtp2',
#   'Tweets Ago': 12},
#  {'Compound': 0.6317,
#   'Date': 'Wed Mar 07 19:35:33 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.804,
#   'Positive': 0.196,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX SEEEEEEEE YOOOOOOOO BY FRIDAY AT $330.00 AFTER  $360 ON APRL 20 SO BUY CALLS LIKE ME https://t.co/UuktezNqEW',
#   'Tweets Ago': 13},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 16:51:49 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '12:00 PM EST: #SwingTrading Midday Review - Compound Trading $LTBR, $ANF, $MOMO, $APTO, $USOIL, $WTI, $BA, $NFLX… https://t.co/3FFg24hXka',
#   'Tweets Ago': 14},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 14:44:05 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX will close  $328.00 MARK my words',
#   'Tweets Ago': 15},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 08:06:17 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Macquarie Raises Netflix $NFLX Price Target to $330.00 https://t.co/4LzsZnWz1b',
#   'Tweets Ago': 16},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 08:06:13 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Macquarie Raises Netflix $NFLX Price Target to $330.00 https://t.co/KhA8TkHpU1',
#   'Tweets Ago': 17},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 08:00:29 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Macquarie Raises Netflix $NFLX Price Target to $330.00 https://t.co/zPqZXdF93s',
#   'Tweets Ago': 18},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 07:58:54 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Netflix $NFLX Price Target Raised to $345.00 https://t.co/KpnjN5NdMb',
#   'Tweets Ago': 19},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 04:03:23 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'RT @MaslovMateo: Today this AMATEUR trader made $1,112.00 $NFLX $CLSD $CGYL only in @AjAwesomecalls',
#   'Tweets Ago': 20},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:35:48 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Today this AMATEUR trader made $1,112.00 $NFLX $CLSD $CGYL only in @AjAwesomecalls',
#   'Tweets Ago': 21},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 03:16:53 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': "Today's ALL TIME NEW HIGHS, Over $1.00, Closed Up on at least 1.1x  ADV(50) ►►► https://t.co/o69jHrHnDy  including… https://t.co/n4lsXylQZO",
#   'Tweets Ago': 22},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 18:56:28 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX Up another $8.00. Remember those red envelopes? That was old school. Their programming is second to none and going global.',
#   'Tweets Ago': 23},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 18:16:27 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'RT @TraderFlorida: $NFLX Up $39.00+ from suggested buy entry – Price target $345.00\narea. https://t.co/ZAV7tZfX7d',
#   'Tweets Ago': 24},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 17:53:13 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX Up $39.00+ from suggested buy entry – Price target $345.00\narea. https://t.co/ZAV7tZfX7d',
#   'Tweets Ago': 25},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 15:54:55 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX 320.00 $DIS https://t.co/I4NPGNP0Jm',
#   'Tweets Ago': 26},
#  {'Compound': -0.25,
#   'Date': 'Tue Mar 06 14:56:54 +0000 2018',
#   'Negative': 0.111,
#   'Neutral': 0.889,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'lowering shorts for now ...$NUGT bull&lt;25; short or buy write&gt;=28; $NFLX bull&lt;300; short&gt;350; $NVDA bull&lt;240 short&gt;2… https://t.co/P3Q0czu9CH',
#   'Tweets Ago': 27},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:51:18 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Netflix target raised to $400 at Pivotal Research Group  (315.00)\nTold you over &amp; over last week\nThis India News wa… https://t.co/JRD8s0cbcS',
#   'Tweets Ago': 28},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:20:11 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': '$NFLX Max Pain=300.00. Maturity=03/09/2018. #maxpain #options https://t.co/gs2a0034ej https://t.co/5YKwH6Glel',
#   'Tweets Ago': 29},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 13:10:16 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$NFLX',
#   'Tweet Text': 'Mar 06 Tuesday, $NFLX is $319.37 in the premarket\n\nBullish target $320.00\nBearish target $317.09',
#   'Tweets Ago': 30},
#  {'Compound': 0.1511,
#   'Date': 'Thu Mar 08 20:51:03 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.923,
#   'Positive': 0.077,
#   'Symbol': '$GOOG',
#   'Tweet Text': 'https://t.co/VgamejroJw &lt;- Want to make $600,00 In One Year Trading? Check out how this guy did it!  $GOOG $PCLN $VTAE',
#   'Tweets Ago': 1},
#  {'Compound': 0.4588,
#   'Date': 'Thu Mar 08 12:28:22 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.8,
#   'Positive': 0.2,
#   'Symbol': '$GOOG',
#   'Tweet Text': '$GOOG open interest for maturity 03/16/2018. High put=1055.00 High call=1035.00 #maxpain #options… https://t.co/YtQ2m7gKIn',
#   'Tweets Ago': 2},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 05:13:14 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$GOOG',
#   'Tweet Text': 'Alphabet Inc $GOOG CEO Sells $4,357,920.00 in Stock https://t.co/OHuYnRT9t9 #stocks',
#   'Tweets Ago': 3},
#  {'Compound': 0.0,
#   'Date': 'Thu Mar 08 05:13:02 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$GOOG',
#   'Tweet Text': 'Alphabet Inc $GOOG CEO Sells $4,357,920.00 in Stock https://t.co/L8itKCgxLi',
#   'Tweets Ago': 4},
#  {'Compound': 0.1511,
#   'Date': 'Thu Mar 08 00:37:06 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.923,
#   'Positive': 0.077,
#   'Symbol': '$GOOG',
#   'Tweet Text': 'https://t.co/fe98B9OU36 &lt;- Want to make $600,00 In One Year Trading? Check out how this guy did it!  $GOOG $PCLN $VTAE',
#   'Tweets Ago': 5},
#  {'Compound': 0.4588,
#   'Date': 'Wed Mar 07 12:30:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.8,
#   'Positive': 0.2,
#   'Symbol': '$GOOG',
#   'Tweet Text': '$GOOG open interest for maturity 03/16/2018. High put=1055.00 High call=1035.00 #maxpain #options… https://t.co/3g6Tr7Zbo5',
#   'Tweets Ago': 6},
#  {'Compound': 0.1511,
#   'Date': 'Tue Mar 06 15:35:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.923,
#   'Positive': 0.077,
#   'Symbol': '$GOOG',
#   'Tweet Text': 'https://t.co/fe98B9OU36 &lt;- Want to make $600,00 In One Year Trading? Check out how this guy did it!  $GOOG $PCLN $VTAE',
#   'Tweets Ago': 7},
#  {'Compound': 0.4389,
#   'Date': 'Thu Mar 08 14:19:34 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.829,
#   'Positive': 0.171,
#   'Symbol': '$GLD',
#   'Tweet Text': '$DASH Dash price: $514.00 \n\nWe verified that Binance is accepting new users! 💎 🙌  \n\n➡️ https://t.co/QAgdjsIiMP… https://t.co/8R6esdAsmO',
#   'Tweets Ago': 1},
#  {'Compound': 0.5267,
#   'Date': 'Thu Mar 08 03:01:02 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.779,
#   'Positive': 0.221,
#   'Symbol': '$GLD',
#   'Tweet Text': '$GLD is in Upside Tasuki Gap winning 75.00% in the past. https://t.co/l4HCZQQeTd https://t.co/floncPEVgb',
#   'Tweets Ago': 2},
#  {'Compound': 0.4926,
#   'Date': 'Thu Mar 08 01:38:26 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.814,
#   'Positive': 0.186,
#   'Symbol': '$GLD',
#   'Tweet Text': 'Litecoin $LTC is valued at: $188.00 \n\nWe checked! Binance registration is currently open 🤑 💸  \n\n➡️… https://t.co/8O7mTKfCBX',
#   'Tweets Ago': 3},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 17:06:01 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$GLD',
#   'Tweet Text': '$GLD back thru 126.00-126.15 is what I am waiting for to add',
#   'Tweets Ago': 4},
#  {'Compound': 0.0,
#   'Date': 'Wed Mar 07 01:45:30 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$GLD',
#   'Tweet Text': "Here's what I've seen during the AH:\n\n$SPY $269.43, $DIA $245.15, $UVXY $18.13, $VXX $46.08, $CMG $316.00, $V $119.… https://t.co/vt1INiQXL8",
#   'Tweets Ago': 5},
#  {'Compound': 0.0,
#   'Date': 'Tue Mar 06 22:05:07 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 1.0,
#   'Positive': 0.0,
#   'Symbol': '$GLD',
#   'Tweet Text': 'SELL TO OPEN $GLD Strangle @ $2.00\n  SELL $GLD Apr 20 $124 Put\n  SELL $GLD Apr 20 $129 Call\nTarget $1.00',
#   'Tweets Ago': 6},
#  {'Compound': 0.8511,
#   'Date': 'Tue Mar 06 16:25:19 +0000 2018',
#   'Negative': 0.0,
#   'Neutral': 0.683,
#   'Positive': 0.317,
#   'Symbol': '$GLD',
#   'Tweet Text': 'Some flight so safety and profit taking from 10:00 am high \n$TLT $GLD 📈📈\nLast 3 week look like the same\nBuy Friday… https://t.co/3gupdx2PNi',
#   'Tweets Ago': 7}]

# %%
# Convert sentiments to DataFrame
sentiments_df = pd.DataFrame.from_dict(sentiments)
unique_sentiments_df = sentiments_df.drop_duplicates("Tweet Text", keep = "first")
unique_sentiments_df
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 0     0.0000  Thu Mar 08 23:25:53 +0000 2018     0.000    1.000     0.000
# 1     0.0258  Thu Mar 08 14:40:03 +0000 2018     0.187    0.526     0.287
# 2     0.6124  Thu Mar 08 14:35:03 +0000 2018     0.000    0.667     0.333
# 3     0.0258  Thu Mar 08 14:31:04 +0000 2018     0.187    0.526     0.287
# 4     0.0000  Thu Mar 08 14:05:13 +0000 2018     0.000    1.000     0.000
# 5     0.0000  Thu Mar 08 12:10:09 +0000 2018     0.000    1.000     0.000
# 6     0.4810  Thu Mar 08 11:16:35 +0000 2018     0.000    0.885     0.115
# 7     0.0000  Thu Mar 08 05:13:11 +0000 2018     0.000    1.000     0.000
# 8     0.5267  Wed Mar 07 23:01:01 +0000 2018     0.000    0.779     0.221
# 11    0.0000  Wed Mar 07 09:18:41 +0000 2018     0.000    1.000     0.000
# 12    0.0000  Wed Mar 07 08:02:37 +0000 2018     0.000    1.000     0.000
# 13    0.0000  Wed Mar 07 03:55:35 +0000 2018     0.000    1.000     0.000
# 14    0.0000  Wed Mar 07 02:30:24 +0000 2018     0.000    1.000     0.000
# 15    0.0000  Tue Mar 06 21:18:21 +0000 2018     0.000    1.000     0.000
# 16    0.0000  Tue Mar 06 18:02:20 +0000 2018     0.000    1.000     0.000
# 17    0.0000  Tue Mar 06 17:28:07 +0000 2018     0.000    1.000     0.000
# 18    0.0000  Tue Mar 06 17:26:41 +0000 2018     0.000    1.000     0.000
# 19    0.0000  Tue Mar 06 17:24:15 +0000 2018     0.000    1.000     0.000
# 23    0.6124  Tue Mar 06 14:45:04 +0000 2018     0.000    0.667     0.333
# 24    0.6124  Tue Mar 06 14:40:03 +0000 2018     0.000    0.667     0.333
# 25    0.6124  Tue Mar 06 14:35:04 +0000 2018     0.000    0.667     0.333
# 27    0.0000  Tue Mar 06 13:36:06 +0000 2018     0.000    1.000     0.000
# 28    0.2960  Thu Mar 08 19:14:08 +0000 2018     0.000    0.820     0.180
# 29    0.0000  Thu Mar 08 16:05:04 +0000 2018     0.000    1.000     0.000
# 30    0.2960  Thu Mar 08 14:56:42 +0000 2018     0.000    0.804     0.196
# 31    0.1511  Thu Mar 08 13:34:02 +0000 2018     0.000    0.923     0.077
# 32    0.2960  Thu Mar 08 13:07:03 +0000 2018     0.000    0.804     0.196
# 33    0.3595  Thu Mar 08 12:26:41 +0000 2018     0.000    0.878     0.122
# 35    0.3595  Thu Mar 08 12:08:26 +0000 2018     0.000    0.865     0.135
# 36    0.4588  Wed Mar 07 22:26:39 +0000 2018     0.000    0.800     0.200
# ..       ...                             ...       ...      ...       ...
# 58    0.6317  Wed Mar 07 19:35:33 +0000 2018     0.000    0.804     0.196
# 59    0.0000  Wed Mar 07 16:51:49 +0000 2018     0.000    1.000     0.000
# 60    0.0000  Wed Mar 07 14:44:05 +0000 2018     0.000    1.000     0.000
# 61    0.0000  Wed Mar 07 08:06:17 +0000 2018     0.000    1.000     0.000
# 62    0.0000  Wed Mar 07 08:06:13 +0000 2018     0.000    1.000     0.000
# 63    0.0000  Wed Mar 07 08:00:29 +0000 2018     0.000    1.000     0.000
# 64    0.0000  Wed Mar 07 07:58:54 +0000 2018     0.000    1.000     0.000
# 65    0.0000  Wed Mar 07 04:03:23 +0000 2018     0.000    1.000     0.000
# 66    0.0000  Wed Mar 07 03:35:48 +0000 2018     0.000    1.000     0.000
# 67    0.0000  Wed Mar 07 03:16:53 +0000 2018     0.000    1.000     0.000
# 68    0.0000  Tue Mar 06 18:56:28 +0000 2018     0.000    1.000     0.000
# 70    0.0000  Tue Mar 06 17:53:13 +0000 2018     0.000    1.000     0.000
# 71    0.0000  Tue Mar 06 15:54:55 +0000 2018     0.000    1.000     0.000
# 72   -0.2500  Tue Mar 06 14:56:54 +0000 2018     0.111    0.889     0.000
# 73    0.0000  Tue Mar 06 13:51:18 +0000 2018     0.000    1.000     0.000
# 74    0.0000  Tue Mar 06 13:20:11 +0000 2018     0.000    1.000     0.000
# 75    0.0000  Tue Mar 06 13:10:16 +0000 2018     0.000    1.000     0.000
# 76    0.1511  Thu Mar 08 20:51:03 +0000 2018     0.000    0.923     0.077
# 77    0.4588  Thu Mar 08 12:28:22 +0000 2018     0.000    0.800     0.200
# 78    0.0000  Thu Mar 08 05:13:14 +0000 2018     0.000    1.000     0.000
# 79    0.0000  Thu Mar 08 05:13:02 +0000 2018     0.000    1.000     0.000
# 80    0.1511  Thu Mar 08 00:37:06 +0000 2018     0.000    0.923     0.077
# 81    0.4588  Wed Mar 07 12:30:07 +0000 2018     0.000    0.800     0.200
# 83    0.4389  Thu Mar 08 14:19:34 +0000 2018     0.000    0.829     0.171
# 84    0.5267  Thu Mar 08 03:01:02 +0000 2018     0.000    0.779     0.221
# 85    0.4926  Thu Mar 08 01:38:26 +0000 2018     0.000    0.814     0.186
# 86    0.0000  Wed Mar 07 17:06:01 +0000 2018     0.000    1.000     0.000
# 87    0.0000  Wed Mar 07 01:45:30 +0000 2018     0.000    1.000     0.000
# 88    0.0000  Tue Mar 06 22:05:07 +0000 2018     0.000    1.000     0.000
# 89    0.8511  Tue Mar 06 16:25:19 +0000 2018     0.000    0.683     0.317
#
#    Symbol                                         Tweet Text  Tweets Ago
# 0     $FB  Facebook Inc $FB CEO Sells $39,908,000.00 in S...           1
# 1     $FB  The price of $fb has just reached a value of 1...           2
# 2     $FB  The price of $fb has just reached a value of 1...           3
# 3     $FB  The price of $fb has just reached a value of 1...           4
# 4     $FB  $FB\n183.71 USD 0.00 (0.00%)\nClosed: Mar 8, 9...           5
# 5     $FB  Insider Selling: Facebook Inc $FB CEO Sells $3...           6
# 6     $FB  RT @Sandro_power: I posted this special update...           7
# 7     $FB  Facebook Inc $FB CEO Sells $39,410,800.00 in S...           8
# 8     $FB  $FB is in Ichimoku Cloud Breakout winning 60.0...           9
# 11    $FB  Facebook Inc $FB CEO Sells $38,500,000.00 in S...          12
# 12    $FB  Facebook COO Sheryl Sandberg Sells $9,610,700....          13
# 13    $FB  907 $FB May 205 Calls bought for $2.083 (sweep...          14
# 14    $FB  Facebook Inc $FB COO Sells $9,610,700.00 in St...          15
# 15    $FB  $FB high OI range is 180.00 to 180.00 for opti...          16
# 16    $FB  $1,020,000.00 of bullish unusual option activi...          17
# 17    $FB                $FB\n12:23 B 2,550 Jun 200 c @ 4.00          18
# 18    $FB  RT @SpeedyCalls: $FB JUN 200.00 Calls BUYING A...          19
# 19    $FB  $FB JUN 200.00 Calls BUYING Activity https://t...          20
# 23    $FB  The price of $fb has just reached a value of 1...          24
# 24    $FB  The price of $fb has just reached a value of 1...          25
# 25    $FB  The price of $fb has just reached a value of 1...          26
# 27    $FB  $FB high OI range is 180.00 to 180.00 for opti...          28
# 28  $AAPL  Apple $AAPL PT Set at $180.00 by Rosenblatt Se...           1
# 29  $AAPL  sold last three $GOOGL 1120c at 7.00 avg from ...           2
# 30  $AAPL  Apple $AAPL Given a $180.00 Price Target at Ro...           3
# 31  $AAPL  https://t.co/0QaRk4AcAV &lt;- Want to make $60...           4
# 32  $AAPL  Apple $AAPL Given a $180.00 Price Target at Ro...           5
# 33  $AAPL  RT @ForexStopHunter: $AAPL Going LIVE with Mic...           6
# 35  $AAPL  $AAPL Going LIVE with Michael Lamothe @Michael...           8
# 36  $AAPL  $AAPL open interest for maturity 03/09/2018. H...           9
# ..    ...                                                ...         ...
# 58  $NFLX  $NFLX SEEEEEEEE YOOOOOOOO BY FRIDAY AT $330.00...          13
# 59  $NFLX  12:00 PM EST: #SwingTrading Midday Review - Co...          14
# 60  $NFLX            $NFLX will close  $328.00 MARK my words          15
# 61  $NFLX  Macquarie Raises Netflix $NFLX Price Target to...          16
# 62  $NFLX  Macquarie Raises Netflix $NFLX Price Target to...          17
# 63  $NFLX  Macquarie Raises Netflix $NFLX Price Target to...          18
# 64  $NFLX  Netflix $NFLX Price Target Raised to $345.00 h...          19
# 65  $NFLX  RT @MaslovMateo: Today this AMATEUR trader mad...          20
# 66  $NFLX  Today this AMATEUR trader made $1,112.00 $NFLX...          21
# 67  $NFLX  Today's ALL TIME NEW HIGHS, Over $1.00, Closed...          22
# 68  $NFLX  $NFLX Up another $8.00. Remember those red env...          23
# 70  $NFLX  $NFLX Up $39.00+ from suggested buy entry – Pr...          25
# 71  $NFLX          $NFLX 320.00 $DIS https://t.co/I4NPGNP0Jm          26
# 72  $NFLX  lowering shorts for now ...$NUGT bull&lt;25; s...          27
# 73  $NFLX  Netflix target raised to $400 at Pivotal Resea...          28
# 74  $NFLX  $NFLX Max Pain=300.00. Maturity=03/09/2018. #m...          29
# 75  $NFLX  Mar 06 Tuesday, $NFLX is $319.37 in the premar...          30
# 76  $GOOG  https://t.co/VgamejroJw &lt;- Want to make $60...           1
# 77  $GOOG  $GOOG open interest for maturity 03/16/2018. H...           2
# 78  $GOOG  Alphabet Inc $GOOG CEO Sells $4,357,920.00 in ...           3
# 79  $GOOG  Alphabet Inc $GOOG CEO Sells $4,357,920.00 in ...           4
# 80  $GOOG  https://t.co/fe98B9OU36 &lt;- Want to make $60...           5
# 81  $GOOG  $GOOG open interest for maturity 03/16/2018. H...           6
# 83   $GLD  $DASH Dash price: $514.00 \n\nWe verified that...           1
# 84   $GLD  $GLD is in Upside Tasuki Gap winning 75.00% in...           2
# 85   $GLD  Litecoin $LTC is valued at: $188.00 \n\nWe che...           3
# 86   $GLD  $GLD back thru 126.00-126.15 is what I am wait...           4
# 87   $GLD  Here's what I've seen during the AH:\n\n$SPY $...           5
# 88   $GLD  SELL TO OPEN $GLD Strangle @ $2.00\n  SELL $GL...           6
# 89   $GLD  Some flight so safety and profit taking from 1...           7
#
# [78 rows x 8 columns]

# %%
# Groupby average compound sentiments by Symbol
ave_sentiment_by_company = unique_sentiments_df.groupby("Symbol")["Compound"].mean()
ave_sentiment_by_company
# Out:
# Symbol
# $AAPL    0.318180
# $AMZN    0.234160
# $FB      0.159495
# $GLD     0.329900
# $GOOG    0.203300
# $NFLX    0.002861
# Name: Compound, dtype: float64

# %%
# Add to Pandas Dataframe
ave_sentiment_by_company_df = pd.DataFrame(ave_sentiment_by_company)
ave_sentiment_by_company_df
# Out:
#         Compound
# Symbol
# $AAPL   0.318180
# $AMZN   0.234160
# $FB     0.159495
# $GLD    0.329900
# $GOOG   0.203300
# $NFLX   0.002861

# %%
# Reset index
sentiment_df = ave_sentiment_by_company_df.reset_index(drop = False)
sentiment_df
# Out:
#   Symbol  Compound
# 0  $AAPL  0.318180
# 1  $AMZN  0.234160
# 2    $FB  0.159495
# 3   $GLD  0.329900
# 4  $GOOG  0.203300
# 5  $NFLX  0.002861

# %%
final_sentiment_df = sentiment_df.replace(("$AAPL", "$AMZN", "$FB", "$GLD", "$GOOG", "$NFLX"), 
                                        ("AAPL", "AMZN", "FB", "GLD", "GOOG", "NFLX"))

final_sentiment_df
# Out:
#   Symbol  Compound
# 0   AAPL  0.318180
# 1   AMZN  0.234160
# 2     FB  0.159495
# 3    GLD  0.329900
# 4   GOOG  0.203300
# 5   NFLX  0.002861

# %%
# merge dataframes
final_df = diff_df.merge(final_sentiment_df, how = "outer")
final_df
# Out:
#   Symbol  Percent_Diff  Compound
# 0   AAPL      2.240452  0.318180
# 1   AMZN      4.570065  0.234160
# 2     FB      4.117109  0.159495
# 3    GLD     -0.004848  0.329900
# 4   GOOG      6.041508  0.203300
# 5   NFLX      7.576157  0.002861

# %%
# Colors
colors = ["lightblue", "green", "red", "blue", "orange", "maroon"]

# Define x-axis and xlabels
x_axis = np.arange(len(final_df))
x_labels = diff_df.index

# %%
# Plot bar graph and assign appropriate parameters
plt.bar(x_axis, final_df["Percent_Diff"], width = 1, tick_label = x_labels,
        color = colors, alpha = 0.75, align = "edge", edgecolor = "black")

tick_locations = [i+0.5 for i in x_axis]
plt.xticks(tick_locations, ["AAPL", "AMZN", "FB", "GLD", "GOOG", "NFLX"])

# Chart Title, x-label and y-label
plt.suptitle("Stock Price Change (%)")
plt.title("03-05-2018 to 03-09-2018")
plt.xlabel("Ticker Symbols")
plt.ylabel("Change in Stock Prices (%)")

# Export and save Bar plot
plt.savefig("PriceChange.png")

# Print chart to the screen
plt.show()

# %%
# Plot bar graph and assign appropriate parameters
plt.bar(x_axis, final_df["Compound"], width = 1, tick_label = x_labels,
        color = colors, alpha = 0.75, align = "edge", edgecolor = "black")

tick_locations = [i+0.5 for i in x_axis]
plt.xticks(tick_locations, ["AAPL", "AMZN", "FB", "GLD", "GOOG", "NFLX"])

# Chart Title, x-label and y-label
plt.suptitle("Sentiment Analysis of Stock Prices based on Twitter")
plt.title("03-05-2018 to 03-09-2018")
plt.xlabel("Ticker Symbols")
plt.ylabel("Tweet Polarity")

# Export and save Bar plot
plt.savefig("Sentiment.png")

# Print chart to the screen
plt.show()

# %%
corr = final_df["Percent_Diff"].corr(final_df["Compound"])
corr
# Out:
# -0.87405767248830535

# %%
x = final_df["Percent_Diff"]
y = final_df["Compound"]
fit = np.polyfit(x, y, 1)
fit_fn = np.poly1d(fit)
plt.plot(x, fit_fn(x), color = 'black')

# %%
# Scatter Correlation plot
plt.scatter(final_df["Percent_Diff"], final_df["Compound"],
         s = 100, color = colors, edgecolor = "black")

plt.suptitle("Correlation between Stock Price change and Sentiment")
plt.title("03-05-2018 to 03-09-2018")
plt.xlabel("Stock Price Change (%)")
plt.ylabel("Tweet Polarity")

# Export and save scatter plot
plt.savefig("Correlation.png")

# Print chart to the screen
plt.show()

# %%
from scipy.stats import linregress
linregress(final_df["Percent_Diff"], final_df["Compound"])
# Out:
# LinregressResult(slope=-0.038921492210093805, intercept=0.36717446530246156, rvalue=-0.87405767248830535, pvalue=0.022793389572690944, stderr=0.010816748466719848)
